# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayanik-tech/Data-Science/blob/main/Churn_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.6.0'

# %%
# importing of all the important libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# tesnorflow lib
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# !pwd
# Out:
# /content/drive/My Drive

# %%
# !ls
# Out:
#  15116018733-AENxxxxx3H-G4.zip
# '15116018733-AENxxxxx3H-G4.zip (Unzipped Files)'
# '15116018733-AENxxxxx3H-G4.zip (Unzipped Files) (1)'
# '15116018917-ALIxxxxx9E-G4.zip (Unzipped Files)'
# '2016 Databae.xls'
# 'Attachments_201598.zip (Unzipped Files)'
#  Churn_Modelling.csv
#  Classroom
# 'Colab Notebooks'
# 'Data Science & AI Certification Course Brochure _ Learnbay - 2020.pdf'
#  Documents
#  DSC00224.JPG
#  DSC00225.JPG
#  DSC00226.JPG
#  DSC00227.JPG
#  DSC00228.JPG
#  DSC00230.JPG
#  DSC00231.JPG
#  DSC00232.JPG
#  DSC00233.JPG
#  DSC00234.JPG
#  DSC00235.JPG
#  DSC00236.JPG
#  DSC00237.JPG
#  DSC00238.JPG
#  DSC00239.JPG
#  DSC00240.JPG
#  DSC00241.JPG
#  DSC00242.JPG
#  DSC00243.JPG
#  DSC00244.JPG
#  DSC00245.JPG
#  DSC00246.JPG
#  DSC00247.JPG
#  DSC00248.JPG
#  DSC00249.JPG
#  DSC00251.JPG
#  DSC00252.JPG
#  DSC00253.JPG
#  DSC00254.JPG
#  DSC00257.JPG
#  DSC00258.JPG
#  DSC00259.JPG
#  DSC00260.JPG
#  DSC00269.JPG
#  DSC00270.JPG
#  DSC00271.JPG
#  DSC00272.JPG
# ...

# %%
# reading the file
data = pd.read_csv('Churn_Modelling.csv')
data.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
# Connect google drive with google colab
# !pwd
# Out:
# /content/drive/My Drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  15116018733-AENxxxxx3H-G4.zip
# '15116018733-AENxxxxx3H-G4.zip (Unzipped Files)'
# '15116018733-AENxxxxx3H-G4.zip (Unzipped Files) (1)'
# '15116018917-ALIxxxxx9E-G4.zip (Unzipped Files)'
# '2016 Databae.xls'
# 'Attachments_201598.zip (Unzipped Files)'
#  Churn_Modelling.csv
#  Classroom
# 'Colab Notebooks'
# 'Data Science & AI Certification Course Brochure _ Learnbay - 2020.pdf'
#  Documents
#  DSC00224.JPG
#  DSC00225.JPG
#  DSC00226.JPG
#  DSC00227.JPG
#  DSC00228.JPG
#  DSC00230.JPG
#  DSC00231.JPG
#  DSC00232.JPG
#  DSC00233.JPG
#  DSC00234.JPG
#  DSC00235.JPG
#  DSC00236.JPG
#  DSC00237.JPG
#  DSC00238.JPG
#  DSC00239.JPG
#  DSC00240.JPG
#  DSC00241.JPG
#  DSC00242.JPG
#  DSC00243.JPG
#  DSC00244.JPG
#  DSC00245.JPG
#  DSC00246.JPG
#  DSC00247.JPG
#  DSC00248.JPG
#  DSC00249.JPG
#  DSC00251.JPG
#  DSC00252.JPG
#  DSC00253.JPG
#  DSC00254.JPG
#  DSC00257.JPG
#  DSC00258.JPG
#  DSC00259.JPG
#  DSC00260.JPG
#  DSC00269.JPG
#  DSC00270.JPG
#  DSC00271.JPG
#  DSC00272.JPG
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
# Split X and Y
x = data.iloc[: , 3:13]
y = data.iloc[: , 13]

# %%
print(x)
# Out:
#       CreditScore Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0             619    France  Female  ...          1               1        101348.88
# 1             608     Spain  Female  ...          0               1        112542.58
# 2             502    France  Female  ...          1               0        113931.57
# 3             699    France  Female  ...          0               0         93826.63
# 4             850     Spain  Female  ...          1               1         79084.10
# ...           ...       ...     ...  ...        ...             ...              ...
# 9995          771    France    Male  ...          1               0         96270.64
# 9996          516    France    Male  ...          1               1        101699.77
# 9997          709    France  Female  ...          0               1         42085.58
# 9998          772   Germany    Male  ...          1               0         92888.52
# ...

# %%
print(y)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
Geography_dummies = pd.get_dummies(x.Geography , prefix='Geography')

# %%
Gender_dummies = pd.get_dummies(x.Gender, drop_first=True)

# %%
x = pd.concat([x,Geography_dummies,Gender_dummies], axis =1)

# %%
x= x.drop(columns = ['Geography','Gender'],axis = 1)

# %%
x.head(10)
# Out:
#    CreditScore  Age  Tenure  ...  Geography_Germany  Geography_Spain  Male
# 0          619   42       2  ...                  0                0     0
# 1          608   41       1  ...                  0                1     0
# 2          502   42       8  ...                  0                0     0
# 3          699   39       1  ...                  0                0     0
# 4          850   43       2  ...                  0                1     0
# 5          645   44       8  ...                  0                1     1
# 6          822   50       7  ...                  0                0     1
# 7          376   29       4  ...                  1                0     0
# 8          501   44       4  ...                  0                0     1
# 9          684   27       2  ...                  0                0     1
#
# [10 rows x 12 columns]
